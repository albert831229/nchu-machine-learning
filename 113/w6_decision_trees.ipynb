# %%
# import library and figure setting
import sklearn

import matplotlib.pyplot as plt

plt.rc('font', size=14)
plt.rc('axes', labelsize=14, titlesize=14)
plt.rc('legend', fontsize=14)
plt.rc('xtick', labelsize=10)
plt.rc('ytick', labelsize=10)

# %% [markdown]
# # Load Dataset

# %%
from sklearn.datasets import load_iris

iris = load_iris(as_frame=True)
X_iris = iris.data[["petal length (cm)", "petal width (cm)"]].values
y_iris = iris.target

# %%
print(X_iris[:5])
print(y_iris[:5])
# Out:
# [[1.4 0.2]
#  [1.4 0.2]
#  [1.3 0.2]
#  [1.5 0.2]
#  [1.4 0.2]]
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: target, dtype: int64

# %%
from sklearn.tree import DecisionTreeClassifier

tree_clf = DecisionTreeClassifier(max_depth=2, random_state=42)
tree_clf.fit(X_iris, y_iris)
# Out:
# DecisionTreeClassifier(max_depth=2, random_state=42)

# %% [markdown]
# # Visualize the Tree

# %%
from sklearn.tree import export_graphviz

export_graphviz(
        tree_clf,
        out_file=str("iris_tree.dot"),  # path differs in the book
        feature_names=["petal length (cm)", "petal width (cm)"],
        class_names=iris.target_names,
        rounded=True,
        filled=True
    )

# %%
from graphviz import Source

Source.from_file("iris_tree.dot")

# %% [markdown]
# # Make Predictions

# %%
import numpy as np
import matplotlib.pyplot as plt

# extra code – just formatting details
from matplotlib.colors import ListedColormap
custom_cmap = ListedColormap(['#fafab0', '#9898ff', '#a0faa0'])
plt.figure(figsize=(8, 4))

lengths, widths = np.meshgrid(np.linspace(0, 7.2, 100), np.linspace(0, 3, 100)) # randomly generate 100 observations
X_iris_all = np.c_[lengths.ravel(), widths.ravel()]
y_pred = tree_clf.predict(X_iris_all).reshape(lengths.shape)
plt.contourf(lengths, widths, y_pred, alpha=0.3, cmap=custom_cmap)
for idx, (name, style) in enumerate(zip(iris.target_names, ("yo", "bs", "g^"))):
    plt.plot(X_iris[:, 0][y_iris == idx], X_iris[:, 1][y_iris == idx],
             style, label=f"Iris {name}")

tree_clf_deeper = DecisionTreeClassifier(max_depth=3, random_state=42) # deeper model
tree_clf_deeper.fit(X_iris, y_iris)
th0, th1, th2a, th2b = tree_clf_deeper.tree_.threshold[[0, 2, 3, 6]]
plt.xlabel("Petal length (cm)")
plt.ylabel("Petal width (cm)")
plt.plot([th0, th0], [0, 3], "k-", linewidth=2)
plt.plot([th0, 7.2], [th1, th1], "k--", linewidth=2)
plt.plot([th2a, th2a], [0, th1], "k:", linewidth=2)
plt.plot([th2b, th2b], [th1, 3], "k:", linewidth=2)
plt.text(th0 - 0.05, 1.0, "Depth=0", horizontalalignment="right", fontsize=15)
plt.text(3.2, th1 + 0.02, "Depth=1", verticalalignment="bottom", fontsize=13)
plt.text(th2a + 0.05, 0.5, "(Depth=2)", fontsize=11)
plt.axis([0, 7.2, 0, 3])
plt.legend()

plt.show()

# %%
# estimating class probability
tree_clf.predict_proba([[5, 1.5]]).round(3)
# Out:
# array([[0.   , 0.907, 0.093]])

# %%
tree_clf.predict([[5, 1.5]])
# Out:
# array([1])

# %% [markdown]
# # Regularization Hyperparameters

# %%
from sklearn.datasets import make_moons

X_moons, y_moons = make_moons(n_samples=150, noise=0.2, random_state=42)

tree_clf1 = DecisionTreeClassifier(random_state=42)
tree_clf2 = DecisionTreeClassifier(min_samples_leaf=5, random_state=42)
tree_clf1.fit(X_moons, y_moons)
tree_clf2.fit(X_moons, y_moons)
# Out:
# DecisionTreeClassifier(min_samples_leaf=5, random_state=42)

# %%
def plot_decision_boundary(clf, X, y, axes, cmap):
    x1, x2 = np.meshgrid(np.linspace(axes[0], axes[1], 100),
                         np.linspace(axes[2], axes[3], 100))
    X_new = np.c_[x1.ravel(), x2.ravel()]
    y_pred = clf.predict(X_new).reshape(x1.shape)

    plt.contourf(x1, x2, y_pred, alpha=0.3, cmap=cmap)
    plt.contour(x1, x2, y_pred, cmap="Greys", alpha=0.8)
    colors = {"Wistia": ["#78785c", "#c47b27"], "Pastel1": ["red", "blue"]}
    markers = ("o", "^")
    for idx in (0, 1):
        plt.plot(X[:, 0][y == idx], X[:, 1][y == idx],
                 color=colors[cmap][idx], marker=markers[idx], linestyle="none")
    plt.axis(axes)
    plt.xlabel(r"$x_1$")
    plt.ylabel(r"$x_2$", rotation=0)

fig, axes = plt.subplots(ncols=2, figsize=(10, 4), sharey=True)
plt.sca(axes[0])
plot_decision_boundary(tree_clf1, X_moons, y_moons,
                       axes=[-1.5, 2.4, -1, 1.5], cmap="Wistia")
plt.title("No restrictions")
plt.sca(axes[1])
plot_decision_boundary(tree_clf2, X_moons, y_moons,
                       axes=[-1.5, 2.4, -1, 1.5], cmap="Wistia")
plt.title(f"min_samples_leaf = {tree_clf2.min_samples_leaf}")
plt.ylabel("")
plt.show()

# %%
X_moons_test, y_moons_test = make_moons(n_samples=1000, noise=0.2,
                                        random_state=43)
tree_clf1.score(X_moons_test, y_moons_test)
# Out:
# 0.898

# %%
tree_clf2.score(X_moons_test, y_moons_test)
# Out:
# 0.92

# %% [markdown]
# # Regression Tree

# %%
from sklearn.tree import DecisionTreeRegressor

np.random.seed(42)
X_quad = np.random.rand(200, 1) - 0.5  # a single random input feature
y_quad = X_quad ** 2 + 0.025 * np.random.randn(200, 1) # create a simple quadratic training set

tree_reg = DecisionTreeRegressor(max_depth=2, random_state=42)
tree_reg.fit(X_quad, y_quad)
# Out:
# DecisionTreeRegressor(max_depth=2, random_state=42)

# %%
export_graphviz(
    tree_reg,
    out_file=str("regression_tree.dot"),
    feature_names=["x1"],
    rounded=True,
    filled=True
)
Source.from_file("regression_tree.dot")

# %%
# create a deeper model
tree_reg2 = DecisionTreeRegressor(max_depth=3, random_state=42)
tree_reg2.fit(X_quad, y_quad)
# Out:
# DecisionTreeRegressor(max_depth=3, random_state=42)

# %%
tree_reg.tree_.threshold
# Out:
# array([-0.30265072, -0.40830374, -2.        , -2.        ,  0.27175756,
#        -2.        , -2.        ])

# %%
tree_reg2.tree_.threshold
# Out:
# array([-0.30265072, -0.40830374, -0.45416115, -2.        , -2.        ,
#        -0.37022041, -2.        , -2.        ,  0.27175756, -0.21270403,
#        -2.        , -2.        ,  0.40399227, -2.        , -2.        ])

# %%
def plot_regression_predictions(tree_reg, X, y, axes=[-0.5, 0.5, -0.05, 0.25]):
    x1 = np.linspace(axes[0], axes[1], 500).reshape(-1, 1)
    y_pred = tree_reg.predict(x1)
    plt.axis(axes)
    plt.xlabel("$x_1$")
    plt.plot(X, y, "b.")
    plt.plot(x1, y_pred, "r.-", linewidth=2, label=r"$\hat{y}$")

fig, axes = plt.subplots(ncols=2, figsize=(10, 4), sharey=True)
plt.sca(axes[0])
plot_regression_predictions(tree_reg, X_quad, y_quad)

th0, th1a, th1b = tree_reg.tree_.threshold[[0, 1, 4]]
for split, style in ((th0, "k-"), (th1a, "k--"), (th1b, "k--")):
    plt.plot([split, split], [-0.05, 0.25], style, linewidth=2)
plt.text(th0, 0.16, "Depth=0", fontsize=15)
plt.text(th1a + 0.01, -0.01, "Depth=1", horizontalalignment="center", fontsize=13)
plt.text(th1b + 0.01, -0.01, "Depth=1", fontsize=13)
plt.ylabel("$y$", rotation=0)
plt.legend(loc="upper center", fontsize=16)
plt.title("max_depth=2")

plt.sca(axes[1])
th2s = tree_reg2.tree_.threshold[[2, 5, 9, 12]]
plot_regression_predictions(tree_reg2, X_quad, y_quad)
for split, style in ((th0, "k-"), (th1a, "k--"), (th1b, "k--")):
    plt.plot([split, split], [-0.05, 0.25], style, linewidth=2)
for split in th2s:
    plt.plot([split, split], [-0.05, 0.25], "k:", linewidth=1)
plt.text(th2s[2] + 0.01, 0.15, "Depth=2", fontsize=13)
plt.title("max_depth=3")

plt.show()

# %%
# no restriction vs at least 10 measurement for each leaf
tree_reg1 = DecisionTreeRegressor(random_state=42)
tree_reg2 = DecisionTreeRegressor(random_state=42, min_samples_leaf=10)
tree_reg1.fit(X_quad, y_quad)
tree_reg2.fit(X_quad, y_quad)

x1 = np.linspace(-0.5, 0.5, 500).reshape(-1, 1)
y_pred1 = tree_reg1.predict(x1)
y_pred2 = tree_reg2.predict(x1)

fig, axes = plt.subplots(ncols=2, figsize=(10, 4), sharey=True)

plt.sca(axes[0])
plt.plot(X_quad, y_quad, "b.")
plt.plot(x1, y_pred1, "r.-", linewidth=2, label=r"$\hat{y}$")
plt.axis([-0.5, 0.5, -0.05, 0.25])
plt.xlabel("$x_1$")
plt.ylabel("$y$", rotation=0)
plt.legend(loc="upper center")
plt.title("No restrictions")

plt.sca(axes[1])
plt.plot(X_quad, y_quad, "b.")
plt.plot(x1, y_pred2, "r.-", linewidth=2, label=r"$\hat{y}$")
plt.axis([-0.5, 0.5, -0.05, 0.25])
plt.xlabel("$x_1$")
plt.title(f"min_samples_leaf={tree_reg2.min_samples_leaf}")

plt.show()

# %% [markdown]
# # Feature Selection

# %%
tree_clf = DecisionTreeClassifier(max_depth=2, random_state=42)
tree_clf.fit(X_iris, y_iris)
# Out:
# DecisionTreeClassifier(max_depth=2, random_state=42)

# %%
tree_clf.feature_importances_
# Out:
# array([0.56199095, 0.43800905])

# %% [markdown]
# # Fine-Tune the Model
# Grid Search

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {
    'max_depth': [2, 3, 4, 5, 6, 7, 8, 9],
    'min_samples_split': [4, 6, 8, 10, 12]
    }
grid_search = GridSearchCV(DecisionTreeRegressor(), param_grid, cv=3,
                           scoring='neg_root_mean_squared_error')
grid_search.fit(X_quad, y_quad)
# Out:
# GridSearchCV(cv=3, estimator=DecisionTreeRegressor(),
#              param_grid={'max_depth': [2, 3, 4, 5, 6, 7, 8, 9],
#                          'min_samples_split': [4, 6, 8, 10, 12]},
#              scoring='neg_root_mean_squared_error')

# %% [markdown]
# The best hyperparameter combination found:

# %%
grid_search.best_params_
# Out:
# {'max_depth': 5, 'min_samples_split': 10}

# %%
# get the best estimator
grid_search.best_estimator_
# Out:
# DecisionTreeRegressor(max_depth=5, min_samples_split=10)

# %%
cvres = grid_search.cv_results_
for mean_score, params in zip(cvres['mean_test_score'], cvres['params']):
  print(np.sqrt(-mean_score), params)
# Out:
# 0.20773436351929808 {'max_depth': 2, 'min_samples_split': 4}
# 0.20773436351929808 {'max_depth': 2, 'min_samples_split': 6}
# 0.20773436351929808 {'max_depth': 2, 'min_samples_split': 8}
# 0.20773436351929808 {'max_depth': 2, 'min_samples_split': 10}
# 0.20773436351929808 {'max_depth': 2, 'min_samples_split': 12}
# 0.18144211917245567 {'max_depth': 3, 'min_samples_split': 4}
# 0.18144211917245567 {'max_depth': 3, 'min_samples_split': 6}
# 0.1812973778389237 {'max_depth': 3, 'min_samples_split': 8}
# 0.18096254318881533 {'max_depth': 3, 'min_samples_split': 10}
# 0.1817996603741419 {'max_depth': 3, 'min_samples_split': 12}
# 0.1740423236080605 {'max_depth': 4, 'min_samples_split': 4}
# 0.173755697626095 {'max_depth': 4, 'min_samples_split': 6}
# 0.17341014511109973 {'max_depth': 4, 'min_samples_split': 8}
# 0.1712441173891546 {'max_depth': 4, 'min_samples_split': 10}
# 0.17394375636487994 {'max_depth': 4, 'min_samples_split': 12}
# 0.17275234597199526 {'max_depth': 5, 'min_samples_split': 4}
# 0.17206686037796642 {'max_depth': 5, 'min_samples_split': 6}
# 0.16791827567404405 {'max_depth': 5, 'min_samples_split': 8}
# 0.16660039357454764 {'max_depth': 5, 'min_samples_split': 10}
# 0.16807921224752684 {'max_depth': 5, 'min_samples_split': 12}
# 0.1769349458478629 {'max_depth': 6, 'min_samples_split': 4}
# 0.17629895518455282 {'max_depth': 6, 'min_samples_split': 6}
# 0.17228053845835475 {'max_depth': 6, 'min_samples_split': 8}
# 0.17099208535678675 {'max_depth': 6, 'min_samples_split': 10}
# 0.17194067288383194 {'max_depth': 6, 'min_samples_split': 12}
# 0.17729564117264132 {'max_depth': 7, 'min_samples_split': 4}
# 0.1767540982736071 {'max_depth': 7, 'min_samples_split': 6}
# 0.17264571760118916 {'max_depth': 7, 'min_samples_split': 8}
# 0.17102150223159968 {'max_depth': 7, 'min_samples_split': 10}
# 0.1722547555628461 {'max_depth': 7, 'min_samples_split': 12}
# 0.17978264204883845 {'max_depth': 8, 'min_samples_split': 4}
# 0.17920934067187919 {'max_depth': 8, 'min_samples_split': 6}
# 0.1749120275196015 {'max_depth': 8, 'min_samples_split': 8}
# 0.1713957628221257 {'max_depth': 8, 'min_samples_split': 10}
# 0.17306045042915175 {'max_depth': 8, 'min_samples_split': 12}
# 0.17969234358995412 {'max_depth': 9, 'min_samples_split': 4}
# 0.17936755937334647 {'max_depth': 9, 'min_samples_split': 6}
# 0.174952430788151 {'max_depth': 9, 'min_samples_split': 8}
# 0.17148548235767494 {'max_depth': 9, 'min_samples_split': 10}
# 0.17315023398951607 {'max_depth': 9, 'min_samples_split': 12}

# %% [markdown]
# # Sensitivity to axis orientation

# %%
# extra code – this cell generates and saves Figure 6–7

np.random.seed(6)
X_square = np.random.rand(100, 2) - 0.5
y_square = (X_square[:, 0] > 0).astype(np.int64)

angle = np.pi / 4  # 45 degrees
rotation_matrix = np.array([[np.cos(angle), -np.sin(angle)],
                            [np.sin(angle), np.cos(angle)]])
X_rotated_square = X_square.dot(rotation_matrix)

tree_clf_square = DecisionTreeClassifier(random_state=42)
tree_clf_square.fit(X_square, y_square)
tree_clf_rotated_square = DecisionTreeClassifier(random_state=42)
tree_clf_rotated_square.fit(X_rotated_square, y_square)

fig, axes = plt.subplots(ncols=2, figsize=(10, 4), sharey=True)
plt.sca(axes[0])
plot_decision_boundary(tree_clf_square, X_square, y_square,
                       axes=[-0.7, 0.7, -0.7, 0.7], cmap="Pastel1")
plt.sca(axes[1])
plot_decision_boundary(tree_clf_rotated_square, X_rotated_square, y_square,
                       axes=[-0.7, 0.7, -0.7, 0.7], cmap="Pastel1")
plt.ylabel("")

plt.show()

# %%
from sklearn.decomposition import PCA
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler

pca_pipeline = make_pipeline(StandardScaler(), PCA())
X_rotated_square_pca = pca_pipeline.fit_transform(X_rotated_square)
tree_clf_pca = DecisionTreeClassifier(max_depth=2, random_state=42)
tree_clf_pca.fit(X_rotated_square_pca, y_square)
# Out:
# DecisionTreeClassifier(max_depth=2, random_state=42)

# %%
plot_decision_boundary(tree_clf_pca, X_rotated_square_pca, y_square,
                       axes=[-2, 2, -2, 2], cmap="Pastel1")
plt.xlabel("$z_1$")
plt.ylabel("$z_2$", rotation=0)

plt.show()

# %% [markdown]
# # Decision Trees Have High Variance

# %%
X_iris_new = np.delete(X_iris, 70, 0)
y_iris_new = np.delete(np.array(y_iris), 70, 0)
tree_clf_tweaked = DecisionTreeClassifier(max_depth=2, random_state=42)
tree_clf_tweaked.fit(X_iris_new, y_iris_new)
# Out:
# DecisionTreeClassifier(max_depth=2, random_state=42)

# %%
plt.figure(figsize=(8, 4))
y_pred = tree_clf_tweaked.predict(X_iris_all).reshape(lengths.shape)
plt.contourf(lengths, widths, y_pred, alpha=0.3, cmap=custom_cmap)

for idx, (name, style) in enumerate(zip(iris.target_names, ("yo", "bs", "g^"))):
    plt.plot(X_iris_new[:, 0][y_iris_new == idx], X_iris_new[:, 1][y_iris_new == idx],
             style, label=f"Iris {name}")

th0, th1 = tree_clf_tweaked.tree_.threshold[[0, 2]]
plt.plot([0, 7.2], [th0, th0], "k-", linewidth=2)
plt.plot([0, 7.2], [th1, th1], "k--", linewidth=2)
plt.text(1.8, th0 + 0.05, "Depth=0", verticalalignment="bottom", fontsize=15)
plt.text(2.3, th1 + 0.05, "Depth=1", verticalalignment="bottom", fontsize=13)
plt.xlabel("Petal length (cm)")
plt.ylabel("Petal width (cm)")
plt.axis([0, 7.2, 0, 3])
plt.legend()

plt.show()
